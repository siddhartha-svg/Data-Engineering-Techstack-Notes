# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhartha-svg/Data-Engineering-Techstack-Notes/blob/main/1_Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.Python Output

# %% [markdown]
# ### Function : x( ) we can call it as function
#
#
# ```
# print( ) ---- Function
# def ( )
#    return ---- Function
# ```

# %%
#Python is case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print('Gautham Bhuddha')
# Out:
# Gautham Bhuddha

# %%
print(Gautham Bhuddha)
# Out:
#   File "/tmp/ipython-input-2360637207.py", line 1
#     print(Gautham Bhuddha)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ##### In above we haven't mentioned strings '' inverted commas for text we are getting like that

# %%
print(7)
# Out:
# 7

# %%
print(7.9)
# Out:
# 7.9

# %%
print(True)
# Out:
# True

# %% [markdown]
# Core rule first (VERY IMPORTANT)
# ```
# Python understands only 3 things inside print()
# 1️⃣ Values
# 2️⃣ Variables (that already exist)
# 3️⃣ Expressions
# ```
#
# Without quotes → Python thinks it’s a variable
#
# With quotes → Python knows it’s text (string)
#
#
# ```
# Gautham_Bhuddha = "Enlightened One"
# print(Gautham_Bhuddha)
# ```
# This one will work

# %%
print('Yes',2,3.4,True)
# Out:
# Yes 2 3.4 True

# %%
print('Yes',2,3.4,True,sep='/')
# Out:
# Yes/2/3.4/True

# %%
print([4,6,9])
print({'a':1})
print({"a":1})
# Out:
# [4, 6, 9]
# {'a': 1}
# {'a': 1}

# %% [markdown]
# ##### `print( ) converts all values to strings, joins them using sep, and prints the final result with a newline`.
#
#
# ```
# 'Yes'   2   3.4   True
#    ↓    ↓     ↓      ↓
#  "Yes" "2" "3.4" "True"
#    ↓    ↓     ↓      ↓
#  joined using "/"
#    ↓
#  Yes/2/3.4/True
#
# ```

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('Hello', end='-')
print('World')
# Out:
# Hello-World

# %% [markdown]
# ```
# Step 1️⃣ First line executes
# print('Hello', end='-')
#
# What happens:
# 'Hello' is printed
# Instead of going to new line, Python prints -
#
# So screen now looks like:
# Hello-
#
# (Cursor stays on the same line)
#
# Step 2️⃣ Second line executes
#
# print('World')
# This uses default behavior:
#
# Prints 'World'
# Then moves to next line
#
# So final output becomes:
#
# Hello-World
# ```

# %%
# Default Nature of print()
print(value, sep=' ', end='\n')

# %%
print("Hi", end="!")
# Out:
# Hi!

# %%
print("Hi", end="")
print("There")
# Out:
# HiThere

# %%
end="\n"   # new line (default)
end=" "    # space
end="-"    # dash
end="|"    # pipe
end=""     # nothing
end="***"  # stars

# %%
# Printing in same line (loading, progress)
print("Loading", end="...")

#Formatting output
print("Name", end=": ")
print("Ram")

# Printing patterns
print("*", end="")
print("*", end="")
print("*")

#sep + end together
print("A", "B", "C", sep="-", end="!")

# %%
print("A", end="...")
print("Ram", end=":")
print("Laxman")
# Out:
# A...Ram:Laxman

# %%
print(" Ram ", end=": ")
print("Laxman")
# Out:
#  Ram : Laxman

# %%
#Full print() signature
print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)

# %% [markdown]
# ```
# *objects	What to print
# sep	Between values
# end	After printing
# file	Where to print
# flush	Force output immediately
#
# Beginner golden rules 🥇
# Default end = new line
# Change end → control line behavior
# end="" → same line printing
# print() always ends with something
#
# ```

# %%
#print() for years and never learn file and flush. ---- Need to Learn this one At the end

# %% [markdown]
# # 2.Data Types

# %% [markdown]
# In Python how many types of data we are using known as data types

# %%
# Integer
print(9)
#1*10^308
print(1e308)
print(1e309)
# Out:
# 9
# 1e+308
# inf

# %% [markdown]
# ```
# int — Integer (whole numbers)
# x = 10
#
# Used for
# Counting | Indexing | Loops | IDs
#
# Can do:
# + - * // %
# Comparisons
#
# Can’t:
# Hold decimals
# Index like a list
#
# Secret:
# Python integers have no size limit
# ```

# %%
#Decimal/Float(Programming Language we call it as Float decimal only)
print(8.9)
print(1.7e308)
print(1.7e309)
# Out:
# 8.9
# 1.7e+308
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# ```
# bool — Boolean (True / False)
# is_active = True
#
# Used for
# Conditions
# Decisions
#
# Flags
# Can do:
#
# Logical operations (and, or, not)
#
# Can’t:
# Store more than two values
#
# Secret:
# True == 1
# False == 0
# ```

# %%
# Text/String(Programming language we call text as String)
print('Hello World')

# %% [markdown]
# ```
# str — String (text)
# name = "Ram"
#
# Used for
# Names
# Messages
# File paths
# JSON
#
# Can do:
# Indexing
# Slicing
# Concatenation
#
# Can’t:
# Add number directly
# "10" + 5  # Wromg
#
# Secret:
# Strings are immutable (cannot change)
# ```

# %%
#Complex Number
print(5+8j)
# Out:
# (5+8j)

# %% [markdown]
# ```
# float — Decimal numbers
# pi = 3.14
#
# Used for
# Money
# Measurements
# Percentages
#
# Can do:
# Decimal math
# Can’t:
# Be 100% precise (rounding issues)
#
# Secret:
# 0.1 + 0.2 != 0.3
# ```

# %%
#ListIn Python ---- In  C Language its ---> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionaries
print({'name': 'Siddhartha', 'age': '25', 'Gender': 'M'})
# Out:
# {'name': 'Siddhartha', 'age': '25', 'Gender': 'M'}

# %% [markdown]
# ```
# dict — Key–value pairs (MOST POWERFUL)
# user = {"name": "Ram", "age": 25}
#
# Used for
# APIs
# JSON
# Configs
# Databases
#
# Can do:
# Fast lookup
# Structured data
#
# Can’t:
# Use mutable keys
# Secret:
#
# Dict lookup is O(1)
# ```

# %% [markdown]
# ```
# COLLECTION TYPES (VERY IMPORTANT)
# list — Ordered, changeable
# items = [1, 2, 3]
#
# Used for
# Storing multiple values
# Iteration
#
# Can do:
# Add, remove, update
# Mixed data types
#
# Can’t:
# Be dictionary key
#
# Secret:
# Lists are mutable
# ```

# %% [markdown]
# ```
# tuple — Ordered, NOT changeable
# point = (10, 20)
#
# Used for
# Fixed data
# Coordinates
# Performance
#
# Can do:
# Faster than list
# Used as dict key
#
# Can’t:
# Modify values
# Secret:
#
# Tuples are immutable
# ```

# %% [markdown]
# ```
# set — Unique values only
# nums = {1, 2, 3}
#
# Used for
# Removing duplicates
# Membership checks
#
# Can do:
# Fast lookup
# Math operations
#
# Can’t:
# Store duplicates
# Maintain order
#
# Secret:
# Sets are unordered
# ```

# %% [markdown]
# ```
# SPECIAL TYPES (LESS USED BUT IMPORTANT)
# NoneType
# x = None
#
# Used for
# Empty value
# Default return
#
# Can’t:
# Do math
# Secret:
# None ≠ 0 ≠ ""
# ```

# %% [markdown]
# ```
# HOW TO REMEMBER (EASY TRICK)
# Rule of 3 buckets
#
# 1️⃣ Single value
# int
# float
# str
# bool
#
# 2️⃣ Multiple values
# list
# tuple
# set
#
# 3️⃣ Key–value
# dict
#
# DEVELOPER SECRETS
# Secret
# Use list when data changes
# Use tuple when data must not change
#
# Secret
# Use set to remove duplicates FAST
# unique = set(my_list)
#
# Secret
# Most bugs = wrong data type
# Always check:
# type(x)
#
# Secret
# Convert early, avoid surprises
# age = int(input())
#
# ❌ COMMON MISTAKES
# "5" + 5        # ❌
# [1,2] + 3      # ❌
# {1,2}[0]       # ❌
# ```

# %%
#Type Functon (It shows which data type has been used)
type("Hello")
# Out:
# str

# %%
type(11)
# Out:
# int

# %%
type(1+2j)
# Out:
# complex

# %%
type(11.9)
# Out:
# float

# %%
type([1,2,3])
# Out:
# list

# %%
type(True)
# Out:
# bool

# %%
type((1,2,3,4))
# Out:
# tuple

# %%
type({1,2,3,4})
# Out:
# set

# %%
type({"a":1})
# Out:
# dict

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# #Variables

# %% [markdown]
# ### variables(storing the information we will use it )

# %% [markdown]
# ###### static vs dynamic typing
# ###### statis vs dynamic binding
# ###### stylish declaration techniques

# %%
name = 'siddhartha'
print(name)
# Out:
# siddhartha

# %%
a = 6
b = 5
print( a + b )
# Out:
# 11

# %%
#Dynamic Typing
a = 5

#Static Typing
int a = 5

# %%
#Dynamic Binding
a = "Siddharth"
print(a)
a = 12
print(a)
# Out:
# Siddharth
# 12

# %%
#Static Binding (c / c++ / Java supports )
int a = 11

#Whatever we assign a value it will be same throughout the program

# %%
a = 1
b = 2
c = 3
print (a ,b ,c )

a,b,c = (1,2,3)
print(a,b,c)
# Out:
# 1 2 3
# 1 2 3

# %%
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
# this is second line

# %% [markdown]
# # 4. Keywords and Identifiers

# %% [markdown]
# #######  `Compilation means converting human-readable code into computer-understandable code.`
#
# ```
# Python uses two steps:
# Compile (source code → bytecode)
# Interpret (bytecode → machine actions)
#
# Step-by-step (very simple)
# Step 1: You write Python code
# x = 10
# print(x)
#
# This is called source code.
#
# Step 2: Python COMPILATION happens (automatically)
# Python converts your code into something called bytecode.
# You don’t see this normally
# It happens behind the scenes
# Stored in __pycache__ as .pyc
#  This is compilation in Python
#
# Step 3: Python INTERPRETER runs it
# Python Virtual Machine (PVM) reads bytecode
# Executes it line by line
#
# ```

# %% [markdown]
# ```
# Complete List of Python Keywords (Grouped for Easy Understanding)
# 🟢1. Logical Keywords
# Keyword	  Meaning
# and	      Logical AND
# or	      Logical OR
# not	      Logical NOT
#
#
# 🟢 2. Conditional (Decision Making)
# Keyword	   Meaning
# if	       Condition check
# elif	     Else-if condition
# else
# Otherwise
#
# 🟢 3. Looping
# Keyword	      Meaning
# for	          Loop through items
# while	        Loop while condition true
# break	        Exit loop
# continue       Skip iteration
# pass	        Do nothing (placeholder)
#
#
# 🟢 4. Function & Class
# Keyword       	Meaning
# def           	Define function
# return	        Return value
# class	          Define class
#
#
# 🟢 5. Exception Handling
# Keyword	        Meaning
# try	            Try risky code
# except	        Handle error
# finally	        Always execute
# raise	          Raise exception
# assert	        Debug check
#
#
# 🟢 6. Boolean & None
# Keyword	     Meaning
# True	       Boolean true
# False	       Boolean false
# None	       No value
#
#
# 🟢 7. Variable Scope
# Keyword	    Meaning
# global	    Global variable
# nonlocal	  Enclosing scope
#
#
# 🟢 8. Import & Modules
# Keyword	      Meaning
# import	      Import module
# from	        Import from module
# as	          Alias name
#
#
# 🟢 9. Loop Control / Flow
# Keyword	    Meaning
# in	        Membership
# is	        Identity check
# with      	Context manager
# yield	      Generator output
#
#
# 🟢 10. Async / Advanced (Good to know)
# Keyword	     Meaning
# async      	Asynchronous function
# await	       Wait for async task
#
#
# 🟢 11. Special / Rarely Used
# Keyword	     Meaning
# lambda	     Anonymous function
# del	         Delete object
# match      	Pattern matching (Python 3.10+)
# case	      Used with match
# ```

# %% [markdown]
# ####
# ```
# Dont use above words in anytime in code
# ```

# %% [markdown]
# ## Identifiers
#
# ###### An identifier is the name you give to something in Python so you can refer to it later.
#
# ```
# Identifiers are names of:
# Variables
# Functions
# Classes
# Modules
# Objects
# ```
#
# ```
# if = 10   # Not a vlid identifier because `if` is a keyword   --- Not a identifier
# ```
#
# ```
# ✅ Allowed
# Can contain letters, numbers, _
# Must start with letter or _
# Case-sensitive (age ≠ Age)
#
# ❌ Not allowed
# Cannot start with number
# Cannot contain spaces
# Cannot be a Python keyword
# ```
#
# ```
# Valid One
# name
# _age
# user1
# total_amount
# is_active
# ```
#
# ```
# 1name     # starts with number
# first name # space
# class     # keyword
# total-amt # hyphen
# ```

# %%
1name = "sid"
print(1name)
# Out:
#   File "/tmp/ipython-input-1251404369.py", line 1
#     1name = "sid"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "sid"
print(name1)
# Out:
# sid

# %% [markdown]
# #5.User Input

# %% [markdown]
# ### Dynamic software vs static software
#
#
# ##### Once you type something and add into it input and enter it

# %%
input()
# Out:
# fgh
# 'fgh'

# %%
input(' what is your name')
# Out:
#  what is your namesiddharth
# 'siddharth'

# %%
input('Email')
# Out:
# Emailnetulasiddhartha891@gmail.com
# 'netulasiddhartha891@gmail.com'

# %%
# take input from users and store them in a variable
# add the 2 variables
# print the result

# take input from users and store them in a variable
fnum = input (' This is my first number')
snum = input ('This is my second number')
print(type(fnum),type(snum))
print(fnum,snum)
# add the 2 variables
result = fnum + snum
# print the result
print(result)

#we need to change the data type beacuse we got result as like this string kind of
# Out:
#  This is my first number23
# This is my second number45
# <class 'str'> <class 'str'>
# 23 45
# 2345

# %%
fnum = input (' This is my first number')
snum = input ('This is my second number')
print(type(fnum),type(snum))
print(fnum,snum)
# add the 2 variables
result = int(fnum) + int(snum)
# print the result
print(result)
print(type(fnum))
# Out:
#  This is my first number12
# This is my second number23
# <class 'str'> <class 'str'>
# 12 23
# 35
# <class 'str'>

# %%
fnum = int(input(' This is my first number'))
snum = int(input('This is my second number'))
# add the 2 variables
result = fnum + snum
# print the result
print(result)
type(result)
print(type(result))
# Out:
#  This is my first number49
# This is my second number37
# 86
# <class 'int'>

# %% [markdown]
# ```
# First: what Python REALLY does with your code
#
# Your code (simplified):
#
# fnum = input('This is my first number')
# snum = input('This is my second number')
#
# print(type(fnum), type(snum))
#
# 🔑 BIG RULE (memorize this)
#
# input() ALWAYS returns a string (str)
#
# No matter what you type:
# 10
# 20
# 4.5
#
# 👉 Python stores it as text, not a number.
# So:
# type(fnum)  → str
# type(snum)  → str
#
#
# This is 100% expected ✅
#
# 🧠 Now this line (MOST IMPORTANT)
# result = int(fnum) + int(snum)
#
# What do you think happens vs what actually happens
# ❌ What beginners think:
#
# “I converted fnum into int, so now fnum is int”
#
# ✅ What Python actually does:
# “I temporarily convert the VALUE of fnum to int, use it for calculation, and THROW IT AWAY”
# ⚠️ fnum itself is NOT changed
# 🧠 Why fnum is STILL string after conversion
#
# You later do:
# print(type(fnum))
#
#
# Output:
# <class 'str'>
#
# Why?
# Because this never happened:
# fnum = int(fnum)
#
# You only did:
# int(fnum)
#
#
# 👉 That conversion was used once, not stored.
# 🔥 KEY CONCEPT (THIS IS THE SECRET)
#
# Conversion does NOT modify the variable
# Assignment modifies the variable
#
# Compare these two:
# Case 1 ❌ (temporary)
# int(fnum)
#
# Case 2 ✅ (permanent)
# fnum = int(fnum)
#
#
# Only Case 2 changes fnum.
#
# 🧠 Visual Memory Model (VERY IMPORTANT)
# Think like this:
# fnum  ───▶  "10"   (string)
#
# When you do:
# int(fnum)
#
# Python does:
# "10" → 10 → used → gone ❌
#
#
# But fnum still points to "10".
#
# 🧠 Correct version (if you WANT fnum to become int)
# fnum = int(fnum)
# snum = int(snum)
#
# result = fnum + snum
#
#
# Now:
#
# type(fnum) → int
#
# 🔑 WHY Python behaves this way (important understanding)
# Strings are immutable
# int() creates a new object
# Python never changes the old object automatically
# You must explicitly assign
#
# 👉 Python avoids hidden side effects
#
# 🧠 WHEN THIS USUALLY HAPPENS (very common)
#
# This confusion happens when:
# Using input()
# Doing type conversion
# Doing math with user input
# Learning Python for the first time 😄
# You are EXACTLY where you should be 👍
#
# 🔥 Common beginner traps (avoid these)
# ❌ Trap 1
# int(fnum)
# print(type(fnum))  # still str
#
# ❌ Trap 2
# result = fnum + snum   # string concatenation
#
# ✅ Correct thinking
# number = int(fnum)
#
# 🧠 SIMPLE RULE TO REMEMBER FOREVER
# If you want to change a variable, assign it back
# Say this in your head:
# “Convert → assign → use”
#
# 🎯 Interview-style one-liner
# input() returns a string, and type conversion functions like int() return a new value. The original variable remains unchanged unless reassigned.
#
# 🧠 3 QUICK TIPS & SECRETS
# 🔹 Tip 1: Always convert input early
# age = int(input("Enter age: "))
#
# 🔹 Tip 2: Print types while learning
# print(type(variable))
#
# 🔹 Tip 3: Think in objects, not variables
#
# Variables just point to values.
# ```

# %% [markdown]
# #6.Type Conversion

# %%
#Implicit and Explicit


#Implicit
print(5+5.6)
print(type(5),type(5.6))
type(5)
# Out:
# 10.6
# <class 'int'> <class 'float'>
# int

# %%
#Explicit
print(5 + '6')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2574252552.py in <cell line: 0>()
#       1 #Explicit
# ----> 2 print(5 + '6')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
int('4')
# Out:
# 4

# %%
#str ---> Integer
int('4')
type(int('4'))
# Out:
# int

# %%
type(int(4.5))
# Out:
# int

# %% [markdown]
# ```
# My doubt is why cant we change this type(int('4.5')) and keep it like this . we are getting error why
#
#
# Now here is  👉 int() converts a value into an integer, but only if Python knows how to convert it safely.
# ```
# ```
# Case 1️⃣
# type(int('4'))
# What is '4'?
# It’s a string
# But it represents a whole number
# Python thinks:
# “Okay, this string looks exactly like an integer.”
# So:
# int('4')  →  4
# type(...) → int
# ✅ Valid
#
#
# Case 2
# type(int(4.5))
#
# What is 4.5?
# It’s a float
# Python rule:
# “When converting float → int, I will drop the decimal part (not round).”
# So:
#
# int(4.5) → 4
# type(...) → int
#
#
# ✅ Valid (but decimal is lost)
# Case 3 (Your main doubt ❗)
# ❌ type(int('4.5'))
# What is '4.5'?
# It’s a string
#
# It contains a decimal point
# Python now thinks:
# “This is NOT a pure integer string.”
# So Python says:
# ValueError: invalid literal for int()
# ❌ Not allowed
#
# 🧠 VERY IMPORTANT RULE (This clears everything)
# int() only accepts:
# Integers
# Strings that look like whole numbers
#
# ✅ Allowed:
# int('10')
# int('-3')
# int(5.9)
#
#
# ❌ Not allowed:
# int('4.5')
# int('3.14')
# int('ten')
#
# ✅ Then how DO we convert '4.5' properly?
# You must go step by step, like Python wants.
# Correct thinking:
# '4.5' → looks like a float
# Convert string → float
# Convert float → int
# int(float('4.5'))
#
#
# Now Python is happy 😄
# 🧠 Why Python is strict here (important concept)
# Python does not guess.
# If Python allowed:
# int('4.5')
# ```

# %%
int(4+5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1226094765.py in <cell line: 0>()
# ----> 1 int(4+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# ```
# These strings can be converted:
#
# float("4")        # 4.0
# float("4.0")      # 4.0
# float("0.5")      # 0.5
# float("-3.2")     # -3.2
# float("10")       # 10.0
# ```
#
#
#
# ```
# INVALID String → Float Conversions
#
# These will FAIL:
#
# float("4.5.6")   # ❌ multiple dots
# float("abc")     # ❌ letters
# float("4,5")     # ❌ comma
# float(" ")       # ❌ empty space
# float("ten")     # ❌ word
# ```
#
#
#
# ```
# value = "4.9"
# num = int(float(value))
# Steps:
# "4.9" → float → 4.9
# 4.9 → int → 4
# 👉 Decimal is cut, not rounded
# ```

# %% [markdown]
# ```
# TYPE CONVERSION MAP (Python)
# 🔵 INTEGER (int) → What can it convert to?
# Convert to	    How	           Works?
# float        	 float(5)	      ✅
# str	             str(5)	          ✅
# bool	         bool(5)	      ✅ (True)
# int	             int(5)	          ✅ (same)
#
# ❌ Cannot convert directly to:
#
# list, dict, set (without logic)
#
# 🔵 FLOAT (float) → What can it convert to?
# Convert to	   How	        Works?
# int	         int(4.7)	               ✅ (decimal lost)
# str	         str(4.7)	               ✅
# bool	       bool(0.0)               ✅ (False)
# float	       float(4.7)              ✅
#
# ❌ Direct conversion issues:
#
# Float string with letters → error
#
# 🔵 STRING (str) → What can it convert to?
# Convert to	         Condition	                  Works?
# int	               string looks like integer	        ✅
# float	            string looks like float       	✅
# bool	            always True if not empty      	⚠️
# str	               always	                        ✅
#
# Examples:
#
# int("10")     # ✅
# float("3.5")  # ✅
# bool("abc")   # True
# bool("")      # False
#
#
# ❌ Errors:
#
# int("3.5")    # ❌
# float("abc")  # ❌
#
# 🔵 BOOLEAN (bool) → What can it convert to?
# Convert      to	                  Result
# int	                           True → 1, False → 0
# float	                         True → 1.0
# str	                            "True" / "False"
# bool	                             same
# 🟢 COLLECTION CONVERSIONS (Bonus)
# From	           To	                     Works?
# list	             tuple	                      ✅
# tuple	             list	                      ✅
# list	             set	                      ✅
# set	                 list	                    ✅
# dict	list	⚠️ keys only
#
# Example:
#
# list((1,2))
# set([1,1,2])
# list({"a":1})   # ['a']
#
# 🧠 HOW TO DECIDE IF CONVERSION IS POSSIBLE (GOLD RULE)
#
# Ask two questions:
#
# 1️⃣ Does the data make sense in the target type?
#
# "abc" → number ❌
#
# "4.5" → float ✅
#
# 2️⃣ Is Python allowed to lose information?
#
# float → int → ❌ decimal lost (allowed)
#
# string → int → ❌ if format unclear
#
# 🔥 SUPER IMPORTANT TRUTHS (REMEMBER THESE)
# 🔹 Truth 1
# input() → always string
# 🔹 Truth 2
# Python never guesses during conversion
# 🔹 Truth 3
# Some conversions lose data (float → int)
#
# 🧠 ONE-LINE MEMORY FORMULA
# Numbers ↔ Numbers → easy
# Text → Number → only if format matches
# Anything → String → always works
# ```

# %% [markdown]
# #7.Literals

# %%
a = 0b1010   #Binary Literals
b = 100      #Decimal Literals
c = 0o310    #Octal Literal
d = 0x12c    #Hexadecimal Literal



#Float literal
float_1  = 10.5
float_2  = 1.5e2  #1.5*10^2--150
float_3  = 1.5e-3 #1.5*10^-3 ----

#Complex Lieral
x=3.14j

print(a)
print(a, b, c, d)
print(float_1, float_2, float_3)
print(x, x.img, x.real)
# Out:
# 10
# 10 100 200 300
# 10.5 150.0 0.0015

# %%
x=3.14j
print(x.real)
# Out:
# 0.0

# %%
x=3.14j
print(x.imag)
# Out:
# 3.14

# %%
print(1.5e3)
# Out:
# 1500.0

# %%
string = 'This is a python'
strings = "This is a python "
char = "C"
multiline_str = """ This is a multiine string with more than one line code """
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str= r"raw \n string"


print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is a python
# This is a python
# C
#  This is a multiine string with more than one line code
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b", b)

#Here booleans treated as 0 and 1 values in python
# Out:
# a: 5
# b 10

# %%
a = None
print(a)
# Out:
# None

# %%
k
a = 5
b = 6
print('Progam is important')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2625332829.py in <cell line: 0>()
# ----> 1 k
#       2 a = 5
#       3 b = 6
#       4 print('Progam is important')
#
# NameError: name 'k' is not defined

# %%
k = None
a = 5
b = 6
print('Progam is important')
# Out:
# Progam is important

# %%
from google.colab import drive
drive.mount('/content/drive')
